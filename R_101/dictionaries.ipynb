# %%
houses_rowwise <- list(
    list(price_approx_usd = 115910.26,
         surface_covered_in_m2 = 128,
         rooms = 4),
    
    list(price_approx_usd = 48718.17,
         surface_covered_in_m2 = 210,
         rooms = 3),
    
    list(price_approx_usd = 28977.56,
         surface_covered_in_m2 = 58,
         rooms = 2),
    
    list(price_approx_usd = 36932.27,
         surface_covered_in_m2 = 79,
         rooms = 3),
    
    list(price_approx_usd = 83903.51,
         surface_covered_in_m2 = 111,
         rooms = 3)
)

# %%
houses_rowwise
# Out:
# [[1]]
# [[1]]$price_approx_usd
# [1] 115910.3
#
# [[1]]$surface_covered_in_m2
# [1] 128
#
# [[1]]$rooms
# [1] 4
#
#
# [[2]]
# [[2]]$price_approx_usd
# [1] 48718.17
#
# [[2]]$surface_covered_in_m2
# [1] 210
#
# [[2]]$rooms
# [1] 3
#
#
# [[3]]
# [[3]]$price_approx_usd
# [1] 28977.56
#
# [[3]]$surface_covered_in_m2
# [1] 58
#
# [[3]]$rooms
# [1] 2
#
#
# [[4]]
# [[4]]$price_approx_usd
# [1] 36932.27
#
# [[4]]$surface_covered_in_m2
# [1] 79
#
# [[4]]$rooms
# [1] 3
#
#
# [[5]]
# [[5]]$price_approx_usd
# [1] 83903.51
#
# [[5]]$surface_covered_in_m2
# [1] 111
#
# [[5]]$rooms
# [1] 3
